# %%
import jax.numpy as jnp
from jax import grad, vmap, hessian

import jax.ops as jop
from jax.config import config; 
config.update("jax_enable_x64", True)

# numpy
import numpy as onp
from numpy import random 

# Plot
import matplotlib.pyplot as plt

# %%
# up to 2nd derivatives

def kappa(x,y,d,sigma):
    dist2 = jnp.sum((x-y)**2)
    return jnp.exp(-dist2/(2*sigma**2))

def D_wy_kappa(x,y,d, sigma,w):
    dist2 = jnp.sum((x-y)**2)
    val = -jnp.sum(w*(y-x))/(sigma**2)*jnp.exp(-dist2/(2*sigma**2))
    return val

def Delta_y_kappa(x,y,d,sigma):
    dist2 = jnp.sum((x-y)**2)
    val = (-d*(sigma**2)+dist2)/(sigma**4)*jnp.exp(-dist2/(2*sigma**2))
    return val

def D_wx_kappa(x,y,d, sigma,w):
    dist2 = jnp.sum((x-y)**2)
    val = -jnp.sum(w*(x-y))/(sigma**2)*jnp.exp(-dist2/(2*sigma**2))
    return val

# Dx vector
def D_x_kappa(x,y,d, sigma):
    dist2 = jnp.sum((x-y)**2)
    val = -(x-y)/(sigma**2)*jnp.exp(-dist2/(2*sigma**2))
    return val

def D_wx_D_wy_kappa(x,y,d,sigma,wx,wy):
    dist2 = jnp.sum((x-y)**2)
    val = (jnp.sum(wx*wy)/(sigma**2)+jnp.sum(wx*(x-y))*jnp.sum(wy*(y-x))/(sigma**4))*jnp.exp(-dist2/(2*sigma**2))
    return val

# DxDwy vector
def D_x_D_wy_kappa(x,y,d,sigma,wy):
    dist2 = jnp.sum((x-y)**2)
    val = (wy/(sigma**2)+(x-y)*jnp.sum(wy*(y-x))/(sigma**4))*jnp.exp(-dist2/(2*sigma**2))
    return val

def D_wx_Delta_y_kappa(x,y, d,sigma,w):
    dist2 = jnp.sum((x-y)**2)
    val = jnp.sum(w*(x-y))*((sigma**2)*(2+d)-dist2)/(sigma**6)*jnp.exp(-dist2/(2*sigma**2))
    return val


def Delta_x_kappa(x,y,d,sigma):
    dist2 = jnp.sum((x-y)**2)
    val = (-d*(sigma**2)+dist2)/(sigma**4)*jnp.exp(-dist2/(2*sigma**2))
    return val

def Delta_x_D_wy_kappa(x,y, d,sigma,w):
    dist2 = jnp.sum((x-y)**2)
    val = jnp.sum(w*(y-x))*((sigma**2)*(2+d)-dist2)/(sigma**6)*jnp.exp(-dist2/(2*sigma**2))
    return val

def Delta_x_Delta_y_kappa(x,y,d,sigma):
    dist2 = jnp.sum((x-y)**2)
    val = ((sigma**4)*d*(2+d)-2*(sigma**2)*(2+d)*dist2+dist2**2)/(sigma**8)*jnp.exp(-dist2/(2*sigma**2))
    return val

def get_GNkernel_train(x,y,wx0,wx1,wy0,wy1,d,sigma):
    return wx0*wy0*kappa(x,y,d,sigma) + wx0*D_wy_kappa(x,y,d, sigma,wy1) + wy0* D_wx_kappa(x,y,d, sigma,wx1) + D_wx_D_wy_kappa(x,y,d,sigma,wx1,wy1)

def get_GNkernel_val_predict(x,y,wy0,wy1,d,sigma):
    return wy0*kappa(x,y,d,sigma) + D_wy_kappa(x,y,d, sigma,wy1)

def get_GNkernel_grad_predict(x,y,wy0,wy1,d,sigma):
    return wy0*D_x_kappa(x,y,d, sigma) + D_x_D_wy_kappa(x,y,d,sigma,wy1)

# %%
def g(x):
    return jnp.log(1/2+1/2*sum(x**2))

# %%
def assembly_Theta(X_domain, w0, w1, sigma):
    # X_domain, dim: N_domain*d; 
    # w0 col vec: coefs of Diracs, dim: N_domain; 
    # w1 coefs of gradients, dim: N_domain*d
    
    N_domain,d = onp.shape(X_domain)
    Theta = onp.zeros((N_domain,N_domain))
    
    XdXd0 = onp.reshape(onp.tile(X_domain,(1,N_domain)),(-1,d))
    XdXd1 = onp.tile(X_domain,(N_domain,1))
    
    arr_wx0 = onp.reshape(onp.tile(w0,(1,N_domain)),(-1,1))
    arr_wx1 = onp.reshape(onp.tile(w1,(1,N_domain)),(-1,d))
    arr_wy0 = onp.tile(w0,(N_domain,1))
    arr_wy1 = onp.tile(w1,(N_domain,1))
    
    val = vmap(lambda x,y,wx0,wx1,wy0,wy1: get_GNkernel_train(x,y,wx0,wx1,wy0,wy1,d,sigma))(XdXd0,XdXd1,arr_wx0,arr_wx1,arr_wy0,arr_wy1)
    Theta[:N_domain,:N_domain] = onp.reshape(val, (N_domain,N_domain))
    return Theta
    
def assembly_Theta_value_and_grad_predict(X_infer, X_domain, w0, w1, sigma):
    N_infer, d = onp.shape(X_infer)
    N_domain, _ = onp.shape(X_domain)
    Theta = onp.zeros((N_infer*(d+1),N_domain))
    
    XiXd0 = onp.reshape(onp.tile(X_infer,(1,N_domain)),(-1,d))
    XiXd1 = onp.tile(X_domain,(N_infer,1))
    
    arr_wy0 = onp.tile(w0,(N_infer,1))
    arr_wy1 = onp.tile(w1,(N_infer,1))
    
    val = vmap(lambda x,y,wy0,wy1: get_GNkernel_val_predict(x,y,wy0,wy1,d,sigma))(XiXd0,XiXd1,arr_wy0,arr_wy1)
    Theta[:N_infer,:N_domain] = onp.reshape(val, (N_infer,N_domain))

    val = vmap(lambda x,y,wy0,wy1: get_GNkernel_grad_predict(x,y,wy0,wy1,d,sigma))(XiXd0,XiXd1,arr_wy0,arr_wy1)
    Theta[N_infer:,:N_domain] = onp.reshape(val,(N_infer*d,N_domain))
    return Theta
    
def assembly_Theta_stanGP(X_domain,sigma):
    N_domain,d = onp.shape(X_domain)
    Theta = onp.zeros((N_domain,N_domain))
    
    XdXd0 = onp.reshape(onp.tile(X_domain,(1,N_domain)),(-1,d))
    XdXd1 = onp.tile(X_domain,(N_domain,1))
    
    val = vmap(lambda x,y: kappa(x,y,d,sigma))(XdXd0,XdXd1)
    Theta[:N_domain,:N_domain] = onp.reshape(val, (N_domain,N_domain))
    return Theta
    
def assembly_Theta_predict_value_and_grad_stanGP(X_infer, X_domain,sigma):
    N_infer,d = onp.shape(X_infer)
    N_domain = onp.shape(X_domain)[0]
    Theta = onp.zeros((N_infer*(d+1),N_domain))
    
    XdXd0 = onp.reshape(onp.tile(X_infer,(1,N_domain)),(-1,d))
    XdXd1 = onp.tile(X_domain,(N_infer,1))
    
    val = vmap(lambda x,y: kappa(x,y,d,sigma))(XdXd0,XdXd1)
    Theta[:N_infer,:N_domain] = onp.reshape(val, (N_infer,N_domain))
    val = vmap(lambda x,y: D_x_kappa(x,y,d,sigma))(XdXd0,XdXd1)
    Theta[N_infer:,:N_domain] = onp.reshape(val,(N_infer*d,N_domain))
    return Theta

# %%
def generate_path(X_init, N_domain, dt, T):
    if onp.ndim(X_init)==1: X_init = X_init[onp.newaxis,:]
    _,d = onp.shape(X_init)
    Nt = int(T/dt)+1
    arr_X = onp.zeros((Nt,N_domain,d))
    arr_X[0,:,:] = X_init
    rdn = onp.random.normal(0, 1, (Nt-1, N_domain,d))
    for i in range(Nt-1):
        arr_X[i+1,:,:] = arr_X[i,:,:] + onp.sqrt(2*dt)*rdn[i,:,:]
    return arr_X

def one_step_iteration(V_future, X_future, X_now, dt, sigma, nugget, GN_step):
    N_domain = onp.shape(X_now)[0]
    Theta_train = assembly_Theta_stanGP(X_future,sigma)
    Theta_infer = assembly_Theta_predict_value_and_grad_stanGP(X_now, X_future,sigma)
    
    V_val_n_grad = Theta_infer @ (onp.linalg.solve(Theta_train + nugget*onp.eye(onp.shape(Theta_train)[0]),V_future))
    w0 = onp.ones((N_domain,1))
    for i in range(GN_step):
        # get grad V_{old}
        V_old = V_val_n_grad[:N_domain]
        print('GN step', i, ' and sol val at 1st point', V_old[0])
        V_old_grad = onp.reshape(V_val_n_grad[N_domain:],(N_domain,d))
        
        w1 = 2*V_old_grad+(X_future-X_now)
        Theta_train = assembly_Theta(X_now, w0, w1, sigma)
        Theta_infer = assembly_Theta_value_and_grad_predict(X_now, X_now, w0, w1, sigma)
        rhs = V_future + onp.sum(V_old_grad**2,axis=1)*dt
        V_val_n_grad = Theta_infer @ (onp.linalg.solve(Theta_train + nugget*onp.eye(onp.shape(Theta_train)[0]),rhs))
    
    return V_val_n_grad[:N_domain]


def GPsolver(X_init, N_domain, dt, T, sigma, nugget, GN_step = 4):
    if onp.ndim(X_init)==1: X_init = X_init[onp.newaxis,:]
    _,d = onp.shape(X_init)
    Nt = int(T/dt)+1
    arr_X = generate_path(X_init, N_domain, dt, T)
    V = onp.zeros((Nt,N_domain))
    V[-1,:] = vmap(g)(arr_X[-1,:,:])
    
    # solve V[-i-1,:] from V[-i,:]
    for i in onp.arange(1,Nt):
        V[-i-1,:] = one_step_iteration(V[-i,:], arr_X[-i,:,:], arr_X[-i-1,:,:], dt, sigma, nugget, GN_step)
        if i % 10 ==0:
            print(f'time t = {(Nt-i)*dt} solved')
    return V

# %%
d = 10
X_init = onp.zeros((1,d))
N_domain = 500
dt = 1e-2
T = 1
sigma = onp.sqrt(d)*50
nugget = 1e-2
GN_step = 10
V = GPsolver(X_init, N_domain, dt, T, sigma, nugget, GN_step)
# Out:
# GN step 0  and sol val at 1st point 2.2306380987141097
# GN step 1  and sol val at 1st point 2.230264104587036
# GN step 2  and sol val at 1st point 2.2302369972009046
# GN step 3  and sol val at 1st point 2.230243722916981
# GN step 4  and sol val at 1st point 2.2302437359298892
# GN step 5  and sol val at 1st point 2.2302437359001317
# GN step 6  and sol val at 1st point 2.2302437359141436
# GN step 7  and sol val at 1st point 2.2302437359138594
# GN step 8  and sol val at 1st point 2.2302437359136604
# GN step 9  and sol val at 1st point 2.23024373591511
# GN step 0  and sol val at 1st point 2.2396135771697097
# GN step 1  and sol val at 1st point 2.2396497870570613
# GN step 2  and sol val at 1st point 2.2396497163850304
# GN step 3  and sol val at 1st point 2.2396497162713267
# GN step 4  and sol val at 1st point 2.2396497162714657
# GN step 5  and sol val at 1st point 2.2396497162714617
# GN step 6  and sol val at 1st point 2.2396497162714795
# GN step 7  and sol val at 1st point 2.2396497162714724
# GN step 8  and sol val at 1st point 2.239649716271465
# GN step 9  and sol val at 1st point 2.239649716271476
# GN step 0  and sol val at 1st point 2.2479508821069576
# GN step 1  and sol val at 1st point 2.247976543637637
# GN step 2  and sol val at 1st point 2.247976484398471
# GN step 3  and sol val at 1st point 2.247976484384597
# GN step 4  and sol val at 1st point 2.247976484384657
# GN step 5  and sol val at 1st point 2.2479764843846497
# GN step 6  and sol val at 1st point 2.2479764843846586
# GN step 7  and sol val at 1st point 2.2479764843846612
# GN step 8  and sol val at 1st point 2.247976484384664
# GN step 9  and sol val at 1st point 2.247976484384656
# GN step 0  and sol val at 1st point 2.2557057842230863
# GN step 1  and sol val at 1st point 2.255722615756856
# GN step 2  and sol val at 1st point 2.2557225707473174
# GN step 3  and sol val at 1st point 2.2557225707647226
# GN step 4  and sol val at 1st point 2.2557225707647404
# GN step 5  and sol val at 1st point 2.255722570764729
# GN step 6  and sol val at 1st point 2.255722570764741
# GN step 7  and sol val at 1st point 2.25572257076474
# GN step 8  and sol val at 1st point 2.2557225707647355
# GN step 9  and sol val at 1st point 2.2557225707647373
# GN step 0  and sol val at 1st point 2.2632568232017602
# GN step 1  and sol val at 1st point 2.2632667706808127
# GN step 2  and sol val at 1st point 2.263266748560731
# GN step 3  and sol val at 1st point 2.26326674855561
# GN step 4  and sol val at 1st point 2.26326674855562
# GN step 5  and sol val at 1st point 2.2632667485556204
# GN step 6  and sol val at 1st point 2.2632667485556235
# GN step 7  and sol val at 1st point 2.2632667485556155
# GN step 8  and sol val at 1st point 2.26326674855562
# GN step 9  and sol val at 1st point 2.2632667485556253
# GN step 0  and sol val at 1st point 2.2672199159978685
# GN step 1  and sol val at 1st point 2.2672239447655826
# GN step 2  and sol val at 1st point 2.267223944851163
# GN step 3  and sol val at 1st point 2.2672239448511298
# GN step 4  and sol val at 1st point 2.267223944851129
# GN step 5  and sol val at 1st point 2.267223944851133
# GN step 6  and sol val at 1st point 2.267223944851133
# GN step 7  and sol val at 1st point 2.267223944851128
# GN step 8  and sol val at 1st point 2.2672239448511298
# GN step 9  and sol val at 1st point 2.267223944851133
# GN step 0  and sol val at 1st point 2.2691124458348306
# GN step 1  and sol val at 1st point 2.2691151458322087
# GN step 2  and sol val at 1st point 2.2691151230814897
# GN step 3  and sol val at 1st point 2.2691151230850126
# GN step 4  and sol val at 1st point 2.269115123085011
# GN step 5  and sol val at 1st point 2.2691151230850135
# GN step 6  and sol val at 1st point 2.2691151230850126
# GN step 7  and sol val at 1st point 2.269115123085009
# GN step 8  and sol val at 1st point 2.269115123085009
# GN step 9  and sol val at 1st point 2.269115123085009
# GN step 0  and sol val at 1st point 2.268278965479422
# GN step 1  and sol val at 1st point 2.268277194836433
# GN step 2  and sol val at 1st point 2.268277173248188
# GN step 3  and sol val at 1st point 2.268277173250782
# GN step 4  and sol val at 1st point 2.2682771732507847
# GN step 5  and sol val at 1st point 2.268277173250781
# GN step 6  and sol val at 1st point 2.2682771732507807
# GN step 7  and sol val at 1st point 2.2682771732507834
# GN step 8  and sol val at 1st point 2.2682771732507816
# GN step 9  and sol val at 1st point 2.2682771732507803
# GN step 0  and sol val at 1st point 2.269206430280825
# GN step 1  and sol val at 1st point 2.2692011466570188
# GN step 2  and sol val at 1st point 2.269201147216216
# GN step 3  and sol val at 1st point 2.2692011472159495
# GN step 4  and sol val at 1st point 2.2692011472159566
# GN step 5  and sol val at 1st point 2.269201147215955
# GN step 6  and sol val at 1st point 2.2692011472159517
# GN step 7  and sol val at 1st point 2.2692011472159543
# GN step 8  and sol val at 1st point 2.2692011472159543
# GN step 9  and sol val at 1st point 2.2692011472159543
# GN step 0  and sol val at 1st point 2.2703791530019646
# GN step 1  and sol val at 1st point 2.270372733434902
# GN step 2  and sol val at 1st point 2.270372740939634
# GN step 3  and sol val at 1st point 2.2703727409391283
# GN step 4  and sol val at 1st point 2.270372740939128
# GN step 5  and sol val at 1st point 2.2703727409391314
# GN step 6  and sol val at 1st point 2.2703727409391288
# GN step 7  and sol val at 1st point 2.2703727409391288
# GN step 8  and sol val at 1st point 2.2703727409391288
# GN step 9  and sol val at 1st point 2.2703727409391288
# time t = 0.91 solved
# GN step 0  and sol val at 1st point 2.270658889699048
# GN step 1  and sol val at 1st point 2.2706522364930946
# GN step 2  and sol val at 1st point 2.2706522286016457
# GN step 3  and sol val at 1st point 2.270652228600861
# GN step 4  and sol val at 1st point 2.2706522286008566
# GN step 5  and sol val at 1st point 2.270652228600858
# GN step 6  and sol val at 1st point 2.27065222860086
# GN step 7  and sol val at 1st point 2.2706522286008606
# GN step 8  and sol val at 1st point 2.2706522286008566
# GN step 9  and sol val at 1st point 2.27065222860086
# GN step 0  and sol val at 1st point 2.2710168924226766
# GN step 1  and sol val at 1st point 2.2710089261076156
# GN step 2  and sol val at 1st point 2.271008923254906
# GN step 3  and sol val at 1st point 2.271008923255845
# GN step 4  and sol val at 1st point 2.2710089232558457
# GN step 5  and sol val at 1st point 2.2710089232558457
# GN step 6  and sol val at 1st point 2.2710089232558457
# GN step 7  and sol val at 1st point 2.2710089232558457
# GN step 8  and sol val at 1st point 2.2710089232558457
# GN step 9  and sol val at 1st point 2.2710089232558457
# GN step 0  and sol val at 1st point 2.272115641469481
# GN step 1  and sol val at 1st point 2.2721070369091803
# GN step 2  and sol val at 1st point 2.27210703821381
# GN step 3  and sol val at 1st point 2.2721070382138224
# GN step 4  and sol val at 1st point 2.2721070382138198
# GN step 5  and sol val at 1st point 2.272107038213823
# GN step 6  and sol val at 1st point 2.2721070382138215
# GN step 7  and sol val at 1st point 2.2721070382138215
# GN step 8  and sol val at 1st point 2.2721070382138215
# GN step 9  and sol val at 1st point 2.2721070382138215
# GN step 0  and sol val at 1st point 2.2725954585837167
# GN step 1  and sol val at 1st point 2.272587401881599
# GN step 2  and sol val at 1st point 2.2725873994714445
# GN step 3  and sol val at 1st point 2.272587399471754
# GN step 4  and sol val at 1st point 2.272587399471755
# GN step 5  and sol val at 1st point 2.2725873994717545
# GN step 6  and sol val at 1st point 2.272587399471754
# GN step 7  and sol val at 1st point 2.272587399471754
# GN step 8  and sol val at 1st point 2.272587399471754
# GN step 9  and sol val at 1st point 2.272587399471754
# GN step 0  and sol val at 1st point 2.2728829151518375
# GN step 1  and sol val at 1st point 2.272874506184172
# GN step 2  and sol val at 1st point 2.2728745048644217
# GN step 3  and sol val at 1st point 2.272874504864304
# GN step 4  and sol val at 1st point 2.272874504864305
# GN step 5  and sol val at 1st point 2.2728745048643004
# GN step 6  and sol val at 1st point 2.2728745048643013
# GN step 7  and sol val at 1st point 2.2728745048643018
# GN step 8  and sol val at 1st point 2.2728745048643018
# GN step 9  and sol val at 1st point 2.2728745048643018
# GN step 0  and sol val at 1st point 2.2733951381093163
# GN step 1  and sol val at 1st point 2.2733863593963997
# GN step 2  and sol val at 1st point 2.273386362650854
# GN step 3  and sol val at 1st point 2.2733863626506157
# GN step 4  and sol val at 1st point 2.2733863626506166
# GN step 5  and sol val at 1st point 2.2733863626506152
# GN step 6  and sol val at 1st point 2.2733863626506152
# GN step 7  and sol val at 1st point 2.2733863626506152
# GN step 8  and sol val at 1st point 2.2733863626506152
# GN step 9  and sol val at 1st point 2.2733863626506152
# GN step 0  and sol val at 1st point 2.273716474662583
# GN step 1  and sol val at 1st point 2.2737072432820127
# GN step 2  and sol val at 1st point 2.2737072449533198
# GN step 3  and sol val at 1st point 2.2737072449533926
# GN step 4  and sol val at 1st point 2.27370724495339
# GN step 5  and sol val at 1st point 2.2737072449533895
# GN step 6  and sol val at 1st point 2.27370724495339
# GN step 7  and sol val at 1st point 2.27370724495339
# GN step 8  and sol val at 1st point 2.27370724495339
# GN step 9  and sol val at 1st point 2.27370724495339
# GN step 0  and sol val at 1st point 2.273954399345283
# GN step 1  and sol val at 1st point 2.273946428138059
# GN step 2  and sol val at 1st point 2.27394642678882
# GN step 3  and sol val at 1st point 2.273946426788852
# GN step 4  and sol val at 1st point 2.2739464267888545
# GN step 5  and sol val at 1st point 2.2739464267888527
# GN step 6  and sol val at 1st point 2.2739464267888527
# GN step 7  and sol val at 1st point 2.2739464267888527
# GN step 8  and sol val at 1st point 2.2739464267888527
# GN step 9  and sol val at 1st point 2.2739464267888527
# GN step 0  and sol val at 1st point 2.2741614613688177
# GN step 1  and sol val at 1st point 2.274153623213216
# GN step 2  and sol val at 1st point 2.2741536222042464
# GN step 3  and sol val at 1st point 2.2741536222042518
# GN step 4  and sol val at 1st point 2.2741536222042487
# GN step 5  and sol val at 1st point 2.2741536222042495
# GN step 6  and sol val at 1st point 2.2741536222042495
# GN step 7  and sol val at 1st point 2.2741536222042495
# GN step 8  and sol val at 1st point 2.2741536222042495
# GN step 9  and sol val at 1st point 2.2741536222042495
# GN step 0  and sol val at 1st point 2.2740338947195378
# GN step 1  and sol val at 1st point 2.2740251493315142
# GN step 2  and sol val at 1st point 2.27402514925186
# GN step 3  and sol val at 1st point 2.2740251492518717
# GN step 4  and sol val at 1st point 2.2740251492518713
# GN step 5  and sol val at 1st point 2.2740251492518713
# GN step 6  and sol val at 1st point 2.2740251492518713
# GN step 7  and sol val at 1st point 2.2740251492518713
# GN step 8  and sol val at 1st point 2.2740251492518713
# GN step 9  and sol val at 1st point 2.2740251492518713
# time t = 0.81 solved
# GN step 0  and sol val at 1st point 2.2741867062889742
# GN step 1  and sol val at 1st point 2.2741772587209104
# GN step 2  and sol val at 1st point 2.2741772582976045
# GN step 3  and sol val at 1st point 2.274177258297544
# GN step 4  and sol val at 1st point 2.274177258297543
# GN step 5  and sol val at 1st point 2.2741772582975432
# GN step 6  and sol val at 1st point 2.2741772582975432
# GN step 7  and sol val at 1st point 2.2741772582975432
# GN step 8  and sol val at 1st point 2.2741772582975432
# GN step 9  and sol val at 1st point 2.2741772582975432
# GN step 0  and sol val at 1st point 2.27411669336537
# GN step 1  and sol val at 1st point 2.2741070092675537
# GN step 2  and sol val at 1st point 2.2741070090623605
# GN step 3  and sol val at 1st point 2.274107009062387
# GN step 4  and sol val at 1st point 2.2741070090623876
# GN step 5  and sol val at 1st point 2.274107009062389
# GN step 6  and sol val at 1st point 2.274107009062389
# GN step 7  and sol val at 1st point 2.274107009062389
# GN step 8  and sol val at 1st point 2.274107009062389
# GN step 9  and sol val at 1st point 2.274107009062389
# GN step 0  and sol val at 1st point 2.274179035560517
# GN step 1  and sol val at 1st point 2.2741698288943866
# GN step 2  and sol val at 1st point 2.274169829449987
# GN step 3  and sol val at 1st point 2.274169829449927
# GN step 4  and sol val at 1st point 2.274169829449928
# GN step 5  and sol val at 1st point 2.274169829449929
# GN step 6  and sol val at 1st point 2.274169829449929
# GN step 7  and sol val at 1st point 2.274169829449929
# GN step 8  and sol val at 1st point 2.274169829449929
# GN step 9  and sol val at 1st point 2.274169829449929
# GN step 0  and sol val at 1st point 2.274170818071407
# GN step 1  and sol val at 1st point 2.2741615337492385
# GN step 2  and sol val at 1st point 2.274161533867524
# GN step 3  and sol val at 1st point 2.274161533867513
# GN step 4  and sol val at 1st point 2.2741615338675123
# GN step 5  and sol val at 1st point 2.2741615338675123
# GN step 6  and sol val at 1st point 2.2741615338675123
# GN step 7  and sol val at 1st point 2.2741615338675123
# GN step 8  and sol val at 1st point 2.2741615338675123
# GN step 9  and sol val at 1st point 2.2741615338675123
# GN step 0  and sol val at 1st point 2.2742149115915726
# GN step 1  and sol val at 1st point 2.2742057006564798
# GN step 2  and sol val at 1st point 2.2742057004329452
# GN step 3  and sol val at 1st point 2.2742057004328426
# GN step 4  and sol val at 1st point 2.274205700432838
# GN step 5  and sol val at 1st point 2.274205700432839
# GN step 6  and sol val at 1st point 2.274205700432839
# GN step 7  and sol val at 1st point 2.274205700432839
# GN step 8  and sol val at 1st point 2.274205700432839
# GN step 9  and sol val at 1st point 2.274205700432839
# GN step 0  and sol val at 1st point 2.2741001748277916
# GN step 1  and sol val at 1st point 2.274091005214577
# GN step 2  and sol val at 1st point 2.274091004584064
# GN step 3  and sol val at 1st point 2.274091004584042
# GN step 4  and sol val at 1st point 2.2740910045840423
# GN step 5  and sol val at 1st point 2.2740910045840423
# GN step 6  and sol val at 1st point 2.2740910045840423
# GN step 7  and sol val at 1st point 2.2740910045840423
# GN step 8  and sol val at 1st point 2.2740910045840423
# GN step 9  and sol val at 1st point 2.2740910045840423
# GN step 0  and sol val at 1st point 2.274072935182306
# GN step 1  and sol val at 1st point 2.27406377840262
# GN step 2  and sol val at 1st point 2.274063778502624
# GN step 3  and sol val at 1st point 2.274063778502613
# GN step 4  and sol val at 1st point 2.2740637785026134
# GN step 5  and sol val at 1st point 2.2740637785026143
# GN step 6  and sol val at 1st point 2.2740637785026143
# GN step 7  and sol val at 1st point 2.2740637785026143
# GN step 8  and sol val at 1st point 2.2740637785026143
# GN step 9  and sol val at 1st point 2.2740637785026143
# GN step 0  and sol val at 1st point 2.27399926253083
# GN step 1  and sol val at 1st point 2.2739902610763574
# GN step 2  and sol val at 1st point 2.273990261569813
# GN step 3  and sol val at 1st point 2.2739902615698475
# GN step 4  and sol val at 1st point 2.273990261569845
# GN step 5  and sol val at 1st point 2.273990261569845
# GN step 6  and sol val at 1st point 2.273990261569845
# GN step 7  and sol val at 1st point 2.273990261569845
# GN step 8  and sol val at 1st point 2.273990261569845
# GN step 9  and sol val at 1st point 2.273990261569845
# GN step 0  and sol val at 1st point 2.2739744002953115
# GN step 1  and sol val at 1st point 2.273965103556331
# GN step 2  and sol val at 1st point 2.2739651031469696
# GN step 3  and sol val at 1st point 2.2739651031469155
# GN step 4  and sol val at 1st point 2.273965103146914
# GN step 5  and sol val at 1st point 2.2739651031469146
# GN step 6  and sol val at 1st point 2.2739651031469146
# GN step 7  and sol val at 1st point 2.2739651031469146
# GN step 8  and sol val at 1st point 2.2739651031469146
# GN step 9  and sol val at 1st point 2.2739651031469146
# GN step 0  and sol val at 1st point 2.273890602822051
# GN step 1  and sol val at 1st point 2.2738823395389827
# GN step 2  and sol val at 1st point 2.273882340138181
# GN step 3  and sol val at 1st point 2.273882340138173
# GN step 4  and sol val at 1st point 2.273882340138176
# GN step 5  and sol val at 1st point 2.273882340138176
# GN step 6  and sol val at 1st point 2.273882340138176
# GN step 7  and sol val at 1st point 2.273882340138176
# GN step 8  and sol val at 1st point 2.273882340138176
# GN step 9  and sol val at 1st point 2.273882340138176
# time t = 0.71 solved
# GN step 0  and sol val at 1st point 2.273863469519427
# GN step 1  and sol val at 1st point 2.2738540932285956
# GN step 2  and sol val at 1st point 2.2738540935045064
# GN step 3  and sol val at 1st point 2.273854093504493
# GN step 4  and sol val at 1st point 2.2738540935044957
# GN step 5  and sol val at 1st point 2.273854093504495
# GN step 6  and sol val at 1st point 2.273854093504495
# GN step 7  and sol val at 1st point 2.273854093504495
# GN step 8  and sol val at 1st point 2.273854093504495
# GN step 9  and sol val at 1st point 2.273854093504495
# GN step 0  and sol val at 1st point 2.2739386229141276
# GN step 1  and sol val at 1st point 2.2739290437910755
# GN step 2  and sol val at 1st point 2.273929044493436
# GN step 3  and sol val at 1st point 2.2739290444934723
# GN step 4  and sol val at 1st point 2.2739290444934683
# GN step 5  and sol val at 1st point 2.2739290444934683
# GN step 6  and sol val at 1st point 2.2739290444934683
# GN step 7  and sol val at 1st point 2.2739290444934683
# GN step 8  and sol val at 1st point 2.2739290444934683
# GN step 9  and sol val at 1st point 2.2739290444934683
# GN step 0  and sol val at 1st point 2.2739277902700046
# GN step 1  and sol val at 1st point 2.2739186009944685
# GN step 2  and sol val at 1st point 2.2739186008405756
# GN step 3  and sol val at 1st point 2.2739186008405303
# GN step 4  and sol val at 1st point 2.2739186008405285
# GN step 5  and sol val at 1st point 2.273918600840527
# GN step 6  and sol val at 1st point 2.2739186008405277
# GN step 7  and sol val at 1st point 2.2739186008405277
# GN step 8  and sol val at 1st point 2.273918600840527
# GN step 9  and sol val at 1st point 2.2739186008405277
# GN step 0  and sol val at 1st point 2.273972151884101
# GN step 1  and sol val at 1st point 2.2739628480786642
# GN step 2  and sol val at 1st point 2.273962847800312
# GN step 3  and sol val at 1st point 2.27396284780028
# GN step 4  and sol val at 1st point 2.2739628478002745
# GN step 5  and sol val at 1st point 2.2739628478002754
# GN step 6  and sol val at 1st point 2.2739628478002754
# GN step 7  and sol val at 1st point 2.2739628478002754
# GN step 8  and sol val at 1st point 2.2739628478002754
# GN step 9  and sol val at 1st point 2.2739628478002754
# GN step 0  and sol val at 1st point 2.2738552330797015
# GN step 1  and sol val at 1st point 2.273845175454921
# GN step 2  and sol val at 1st point 2.27384517499849
# GN step 3  and sol val at 1st point 2.2738451749984137
# GN step 4  and sol val at 1st point 2.273845174998416
# GN step 5  and sol val at 1st point 2.2738451749984163
# GN step 6  and sol val at 1st point 2.2738451749984163
# GN step 7  and sol val at 1st point 2.2738451749984163
# GN step 8  and sol val at 1st point 2.2738451749984163
# GN step 9  and sol val at 1st point 2.2738451749984163
# GN step 0  and sol val at 1st point 2.2737864229566
# GN step 1  and sol val at 1st point 2.273776338442792
# GN step 2  and sol val at 1st point 2.2737763383773197
# GN step 3  and sol val at 1st point 2.2737763383772895
# GN step 4  and sol val at 1st point 2.273776338377285
# GN step 5  and sol val at 1st point 2.273776338377285
# GN step 6  and sol val at 1st point 2.273776338377285
# GN step 7  and sol val at 1st point 2.273776338377285
# GN step 8  and sol val at 1st point 2.273776338377285
# GN step 9  and sol val at 1st point 2.273776338377285
# GN step 0  and sol val at 1st point 2.2736812650950773
# GN step 1  and sol val at 1st point 2.273672722163199
# GN step 2  and sol val at 1st point 2.2736727216805024
# GN step 3  and sol val at 1st point 2.273672721680466
# GN step 4  and sol val at 1st point 2.273672721680461
# GN step 5  and sol val at 1st point 2.2736727216804615
# GN step 6  and sol val at 1st point 2.273672721680461
# GN step 7  and sol val at 1st point 2.273672721680461
# GN step 8  and sol val at 1st point 2.273672721680461
# GN step 9  and sol val at 1st point 2.273672721680461
# GN step 0  and sol val at 1st point 2.2736450407635678
# GN step 1  and sol val at 1st point 2.2736361555292977
# GN step 2  and sol val at 1st point 2.2736361553539304
# GN step 3  and sol val at 1st point 2.2736361553538833
# GN step 4  and sol val at 1st point 2.2736361553538815
# GN step 5  and sol val at 1st point 2.273636155353881
# GN step 6  and sol val at 1st point 2.273636155353881
# GN step 7  and sol val at 1st point 2.273636155353881
# GN step 8  and sol val at 1st point 2.273636155353881
# GN step 9  and sol val at 1st point 2.273636155353881
# GN step 0  and sol val at 1st point 2.2736394971006497
# GN step 1  and sol val at 1st point 2.273631795072959
# GN step 2  and sol val at 1st point 2.2736317949008003
# GN step 3  and sol val at 1st point 2.2736317949007887
# GN step 4  and sol val at 1st point 2.2736317949007896
# GN step 5  and sol val at 1st point 2.273631794900789
# GN step 6  and sol val at 1st point 2.273631794900789
# GN step 7  and sol val at 1st point 2.273631794900789
# GN step 8  and sol val at 1st point 2.273631794900789
# GN step 9  and sol val at 1st point 2.273631794900789
# GN step 0  and sol val at 1st point 2.2735413702096885
# GN step 1  and sol val at 1st point 2.273532721112339
# GN step 2  and sol val at 1st point 2.273532721539764
# GN step 3  and sol val at 1st point 2.273532721539767
# GN step 4  and sol val at 1st point 2.27353272153977
# GN step 5  and sol val at 1st point 2.2735327215397696
# GN step 6  and sol val at 1st point 2.2735327215397696
# GN step 7  and sol val at 1st point 2.2735327215397696
# GN step 8  and sol val at 1st point 2.2735327215397696
# GN step 9  and sol val at 1st point 2.2735327215397696
# time t = 0.61 solved
# GN step 0  and sol val at 1st point 2.2734860723159054
# GN step 1  and sol val at 1st point 2.2734772832102235
# GN step 2  and sol val at 1st point 2.2734772831603114
# GN step 3  and sol val at 1st point 2.2734772831602963
# GN step 4  and sol val at 1st point 2.273477283160293
# GN step 5  and sol val at 1st point 2.273477283160293
# GN step 6  and sol val at 1st point 2.273477283160293
# GN step 7  and sol val at 1st point 2.273477283160293
# GN step 8  and sol val at 1st point 2.273477283160293
# GN step 9  and sol val at 1st point 2.273477283160293
# GN step 0  and sol val at 1st point 2.273424674041803
# GN step 1  and sol val at 1st point 2.273415674870071
# GN step 2  and sol val at 1st point 2.2734156751861496
# GN step 3  and sol val at 1st point 2.2734156751861985
# GN step 4  and sol val at 1st point 2.273415675186199
# GN step 5  and sol val at 1st point 2.2734156751861994
# GN step 6  and sol val at 1st point 2.2734156751861994
# GN step 7  and sol val at 1st point 2.2734156751861994
# GN step 8  and sol val at 1st point 2.2734156751861994
# GN step 9  and sol val at 1st point 2.2734156751861994
# GN step 0  and sol val at 1st point 2.2734025807948943
# GN step 1  and sol val at 1st point 2.273393817903818
# GN step 2  and sol val at 1st point 2.273393817375678
# GN step 3  and sol val at 1st point 2.273393817375635
# GN step 4  and sol val at 1st point 2.273393817375634
# GN step 5  and sol val at 1st point 2.2733938173756334
# GN step 6  and sol val at 1st point 2.2733938173756334
# GN step 7  and sol val at 1st point 2.2733938173756334
# GN step 8  and sol val at 1st point 2.2733938173756334
# GN step 9  and sol val at 1st point 2.2733938173756334
# GN step 0  and sol val at 1st point 2.2733493441369808
# GN step 1  and sol val at 1st point 2.27334015419609
# GN step 2  and sol val at 1st point 2.2733401545777303
# GN step 3  and sol val at 1st point 2.273340154577784
# GN step 4  and sol val at 1st point 2.273340154577782
# GN step 5  and sol val at 1st point 2.2733401545777814
# GN step 6  and sol val at 1st point 2.2733401545777814
# GN step 7  and sol val at 1st point 2.2733401545777814
# GN step 8  and sol val at 1st point 2.2733401545777814
# GN step 9  and sol val at 1st point 2.2733401545777814
# GN step 0  and sol val at 1st point 2.2733260090113063
# GN step 1  and sol val at 1st point 2.273317508298675
# GN step 2  and sol val at 1st point 2.2733175085745314
# GN step 3  and sol val at 1st point 2.273317508574527
# GN step 4  and sol val at 1st point 2.2733175085745296
# GN step 5  and sol val at 1st point 2.2733175085745287
# GN step 6  and sol val at 1st point 2.2733175085745287
# GN step 7  and sol val at 1st point 2.2733175085745287
# GN step 8  and sol val at 1st point 2.2733175085745287
# GN step 9  and sol val at 1st point 2.2733175085745287
# GN step 0  and sol val at 1st point 2.27320209765025
# GN step 1  and sol val at 1st point 2.2731936260705528
# GN step 2  and sol val at 1st point 2.273193626314333
# GN step 3  and sol val at 1st point 2.2731936263143595
# GN step 4  and sol val at 1st point 2.27319362631436
# GN step 5  and sol val at 1st point 2.27319362631436
# GN step 6  and sol val at 1st point 2.27319362631436
# GN step 7  and sol val at 1st point 2.27319362631436
# GN step 8  and sol val at 1st point 2.27319362631436
# GN step 9  and sol val at 1st point 2.27319362631436
# GN step 0  and sol val at 1st point 2.273202452844444
# GN step 1  and sol val at 1st point 2.2731933952538372
# GN step 2  and sol val at 1st point 2.2731933957417936
# GN step 3  and sol val at 1st point 2.27319339574178
# GN step 4  and sol val at 1st point 2.27319339574178
# GN step 5  and sol val at 1st point 2.27319339574178
# GN step 6  and sol val at 1st point 2.27319339574178
# GN step 7  and sol val at 1st point 2.27319339574178
# GN step 8  and sol val at 1st point 2.27319339574178
# GN step 9  and sol val at 1st point 2.27319339574178
# GN step 0  and sol val at 1st point 2.2732201492463298
# GN step 1  and sol val at 1st point 2.273210487632876
# GN step 2  and sol val at 1st point 2.2732104876664403
# GN step 3  and sol val at 1st point 2.273210487666428
# GN step 4  and sol val at 1st point 2.273210487666428
# GN step 5  and sol val at 1st point 2.273210487666427
# GN step 6  and sol val at 1st point 2.273210487666427
# GN step 7  and sol val at 1st point 2.273210487666427
# GN step 8  and sol val at 1st point 2.273210487666427
# GN step 9  and sol val at 1st point 2.273210487666427
# GN step 0  and sol val at 1st point 2.273216610178715
# GN step 1  and sol val at 1st point 2.2732082895866395
# GN step 2  and sol val at 1st point 2.2732082897593675
# GN step 3  and sol val at 1st point 2.273208289759335
# GN step 4  and sol val at 1st point 2.2732082897593364
# GN step 5  and sol val at 1st point 2.273208289759336
# GN step 6  and sol val at 1st point 2.273208289759336
# GN step 7  and sol val at 1st point 2.273208289759336
# GN step 8  and sol val at 1st point 2.273208289759336
# GN step 9  and sol val at 1st point 2.273208289759336
# GN step 0  and sol val at 1st point 2.273164174169991
# GN step 1  and sol val at 1st point 2.273154844666314
# GN step 2  and sol val at 1st point 2.273154844300187
# GN step 3  and sol val at 1st point 2.273154844300164
# GN step 4  and sol val at 1st point 2.2731548443001626
# GN step 5  and sol val at 1st point 2.2731548443001626
# GN step 6  and sol val at 1st point 2.2731548443001626
# GN step 7  and sol val at 1st point 2.2731548443001626
# GN step 8  and sol val at 1st point 2.2731548443001626
# GN step 9  and sol val at 1st point 2.2731548443001626
# time t = 0.51 solved
# GN step 0  and sol val at 1st point 2.2730939337039526
# GN step 1  and sol val at 1st point 2.2730852765111518
# GN step 2  and sol val at 1st point 2.273085276491078
# GN step 3  and sol val at 1st point 2.2730852764911056
# GN step 4  and sol val at 1st point 2.2730852764911034
# GN step 5  and sol val at 1st point 2.2730852764911034
# GN step 6  and sol val at 1st point 2.2730852764911034
# GN step 7  and sol val at 1st point 2.2730852764911034
# GN step 8  and sol val at 1st point 2.2730852764911034
# GN step 9  and sol val at 1st point 2.2730852764911034
# GN step 0  and sol val at 1st point 2.2731000925471085
# GN step 1  and sol val at 1st point 2.27309047276159
# GN step 2  and sol val at 1st point 2.2730904725211527
# GN step 3  and sol val at 1st point 2.273090472521125
# GN step 4  and sol val at 1st point 2.27309047252112
# GN step 5  and sol val at 1st point 2.2730904725211203
# GN step 6  and sol val at 1st point 2.2730904725211203
# GN step 7  and sol val at 1st point 2.2730904725211203
# GN step 8  and sol val at 1st point 2.2730904725211203
# GN step 9  and sol val at 1st point 2.2730904725211203
# GN step 0  and sol val at 1st point 2.27301065541724
# GN step 1  and sol val at 1st point 2.273002017445753
# GN step 2  and sol val at 1st point 2.2730020174459438
# GN step 3  and sol val at 1st point 2.273002017445951
# GN step 4  and sol val at 1st point 2.273002017445951
# GN step 5  and sol val at 1st point 2.273002017445951
# GN step 6  and sol val at 1st point 2.273002017445951
# GN step 7  and sol val at 1st point 2.273002017445951
# GN step 8  and sol val at 1st point 2.273002017445951
# GN step 9  and sol val at 1st point 2.273002017445951
# GN step 0  and sol val at 1st point 2.272940425649459
# GN step 1  and sol val at 1st point 2.2729308198890505
# GN step 2  and sol val at 1st point 2.272930820087117
# GN step 3  and sol val at 1st point 2.2729308200871468
# GN step 4  and sol val at 1st point 2.27293082008715
# GN step 5  and sol val at 1st point 2.2729308200871503
# GN step 6  and sol val at 1st point 2.2729308200871503
# GN step 7  and sol val at 1st point 2.2729308200871503
# GN step 8  and sol val at 1st point 2.2729308200871503
# GN step 9  and sol val at 1st point 2.2729308200871503
# GN step 0  and sol val at 1st point 2.2729181025592076
# GN step 1  and sol val at 1st point 2.2729087226906612
# GN step 2  and sol val at 1st point 2.2729087225945195
# GN step 3  and sol val at 1st point 2.272908722594515
# GN step 4  and sol val at 1st point 2.272908722594515
# GN step 5  and sol val at 1st point 2.272908722594515
# GN step 6  and sol val at 1st point 2.272908722594515
# GN step 7  and sol val at 1st point 2.272908722594515
# GN step 8  and sol val at 1st point 2.272908722594515
# GN step 9  and sol val at 1st point 2.272908722594515
# GN step 0  and sol val at 1st point 2.2728738591275675
# GN step 1  and sol val at 1st point 2.2728644104590323
# GN step 2  and sol val at 1st point 2.2728644106108176
# GN step 3  and sol val at 1st point 2.272864410610823
# GN step 4  and sol val at 1st point 2.272864410610822
# GN step 5  and sol val at 1st point 2.272864410610822
# GN step 6  and sol val at 1st point 2.272864410610822
# GN step 7  and sol val at 1st point 2.272864410610822
# GN step 8  and sol val at 1st point 2.272864410610822
# GN step 9  and sol val at 1st point 2.272864410610822
# GN step 0  and sol val at 1st point 2.2728604517676976
# GN step 1  and sol val at 1st point 2.2728513024084487
# GN step 2  and sol val at 1st point 2.272851302248787
# GN step 3  and sol val at 1st point 2.2728513022487853
# GN step 4  and sol val at 1st point 2.2728513022487884
# GN step 5  and sol val at 1st point 2.272851302248788
# GN step 6  and sol val at 1st point 2.272851302248788
# GN step 7  and sol val at 1st point 2.272851302248788
# GN step 8  and sol val at 1st point 2.272851302248788
# GN step 9  and sol val at 1st point 2.272851302248788
# GN step 0  and sol val at 1st point 2.272882829853355
# GN step 1  and sol val at 1st point 2.272874249645591
# GN step 2  and sol val at 1st point 2.2728742495534195
# GN step 3  and sol val at 1st point 2.2728742495534022
# GN step 4  and sol val at 1st point 2.272874249553399
# GN step 5  and sol val at 1st point 2.272874249553399
# GN step 6  and sol val at 1st point 2.272874249553399
# GN step 7  and sol val at 1st point 2.272874249553399
# GN step 8  and sol val at 1st point 2.272874249553399
# GN step 9  and sol val at 1st point 2.272874249553399
# GN step 0  and sol val at 1st point 2.272830401902494
# GN step 1  and sol val at 1st point 2.2728211802248364
# GN step 2  and sol val at 1st point 2.2728211803987945
# GN step 3  and sol val at 1st point 2.2728211803988274
# GN step 4  and sol val at 1st point 2.272821180398828
# GN step 5  and sol val at 1st point 2.2728211803988287
# GN step 6  and sol val at 1st point 2.2728211803988287
# GN step 7  and sol val at 1st point 2.2728211803988287
# GN step 8  and sol val at 1st point 2.2728211803988287
# GN step 9  and sol val at 1st point 2.2728211803988287
# GN step 0  and sol val at 1st point 2.2727907842554647
# GN step 1  and sol val at 1st point 2.2727816075914404
# GN step 2  and sol val at 1st point 2.272781607469557
# GN step 3  and sol val at 1st point 2.2727816074695344
# GN step 4  and sol val at 1st point 2.272781607469539
# GN step 5  and sol val at 1st point 2.272781607469539
# GN step 6  and sol val at 1st point 2.272781607469539
# GN step 7  and sol val at 1st point 2.272781607469539
# GN step 8  and sol val at 1st point 2.272781607469539
# GN step 9  and sol val at 1st point 2.272781607469539
# time t = 0.41000000000000003 solved
# GN step 0  and sol val at 1st point 2.27277159368447
# GN step 1  and sol val at 1st point 2.272762265109355
# GN step 2  and sol val at 1st point 2.272762264735303
# GN step 3  and sol val at 1st point 2.2727622647352854
# GN step 4  and sol val at 1st point 2.272762264735284
# GN step 5  and sol val at 1st point 2.272762264735285
# GN step 6  and sol val at 1st point 2.272762264735285
# GN step 7  and sol val at 1st point 2.272762264735285
# GN step 8  and sol val at 1st point 2.272762264735285
# GN step 9  and sol val at 1st point 2.272762264735285
# GN step 0  and sol val at 1st point 2.272746752069847
# GN step 1  and sol val at 1st point 2.272737952716346
# GN step 2  and sol val at 1st point 2.272737952343892
# GN step 3  and sol val at 1st point 2.27273795234383
# GN step 4  and sol val at 1st point 2.2727379523438316
# GN step 5  and sol val at 1st point 2.2727379523438316
# GN step 6  and sol val at 1st point 2.2727379523438316
# GN step 7  and sol val at 1st point 2.2727379523438316
# GN step 8  and sol val at 1st point 2.2727379523438316
# GN step 9  and sol val at 1st point 2.2727379523438316
# GN step 0  and sol val at 1st point 2.272651321434517
# GN step 1  and sol val at 1st point 2.27264274221677
# GN step 2  and sol val at 1st point 2.2726427421284154
# GN step 3  and sol val at 1st point 2.272642742128383
# GN step 4  and sol val at 1st point 2.272642742128382
# GN step 5  and sol val at 1st point 2.272642742128382
# GN step 6  and sol val at 1st point 2.272642742128382
# GN step 7  and sol val at 1st point 2.272642742128382
# GN step 8  and sol val at 1st point 2.272642742128382
# GN step 9  and sol val at 1st point 2.272642742128382
# GN step 0  and sol val at 1st point 2.272692139822548
# GN step 1  and sol val at 1st point 2.272683264081022
# GN step 2  and sol val at 1st point 2.2726832643654
# GN step 3  and sol val at 1st point 2.272683264365391
# GN step 4  and sol val at 1st point 2.2726832643653916
# GN step 5  and sol val at 1st point 2.2726832643653916
# GN step 6  and sol val at 1st point 2.2726832643653916
# GN step 7  and sol val at 1st point 2.2726832643653916
# GN step 8  and sol val at 1st point 2.2726832643653916
# GN step 9  and sol val at 1st point 2.2726832643653916
# GN step 0  and sol val at 1st point 2.2726185592972348
# GN step 1  and sol val at 1st point 2.2726100776261013
# GN step 2  and sol val at 1st point 2.272610077619441
# GN step 3  and sol val at 1st point 2.272610077619427
# GN step 4  and sol val at 1st point 2.2726100776194302
# GN step 5  and sol val at 1st point 2.2726100776194302
# GN step 6  and sol val at 1st point 2.2726100776194302
# GN step 7  and sol val at 1st point 2.2726100776194302
# GN step 8  and sol val at 1st point 2.2726100776194302
# GN step 9  and sol val at 1st point 2.2726100776194302
# GN step 0  and sol val at 1st point 2.2725773759698695
# GN step 1  and sol val at 1st point 2.272566996058852
# GN step 2  and sol val at 1st point 2.27256699605351
# GN step 3  and sol val at 1st point 2.272566996053504
# GN step 4  and sol val at 1st point 2.2725669960535013
# GN step 5  and sol val at 1st point 2.2725669960535013
# GN step 6  and sol val at 1st point 2.2725669960535013
# GN step 7  and sol val at 1st point 2.2725669960535013
# GN step 8  and sol val at 1st point 2.2725669960535013
# GN step 9  and sol val at 1st point 2.2725669960535013
# GN step 0  and sol val at 1st point 2.2725953754045327
# GN step 1  and sol val at 1st point 2.2725864983228585
# GN step 2  and sol val at 1st point 2.272586498386276
# GN step 3  and sol val at 1st point 2.272586498386257
# GN step 4  and sol val at 1st point 2.2725864983862563
# GN step 5  and sol val at 1st point 2.2725864983862563
# GN step 6  and sol val at 1st point 2.2725864983862563
# GN step 7  and sol val at 1st point 2.2725864983862563
# GN step 8  and sol val at 1st point 2.2725864983862563
# GN step 9  and sol val at 1st point 2.2725864983862563
# GN step 0  and sol val at 1st point 2.27258475667548
# GN step 1  and sol val at 1st point 2.2725751516418335
# GN step 2  and sol val at 1st point 2.272575151692233
# GN step 3  and sol val at 1st point 2.2725751516922754
# GN step 4  and sol val at 1st point 2.272575151692278
# GN step 5  and sol val at 1st point 2.272575151692279
# GN step 6  and sol val at 1st point 2.272575151692279
# GN step 7  and sol val at 1st point 2.272575151692279
# GN step 8  and sol val at 1st point 2.272575151692279
# GN step 9  and sol val at 1st point 2.272575151692279
# GN step 0  and sol val at 1st point 2.2725405527212397
# GN step 1  and sol val at 1st point 2.272532120565394
# GN step 2  and sol val at 1st point 2.2725321206147915
# GN step 3  and sol val at 1st point 2.2725321206148017
# GN step 4  and sol val at 1st point 2.272532120614804
# GN step 5  and sol val at 1st point 2.272532120614804
# GN step 6  and sol val at 1st point 2.272532120614804
# GN step 7  and sol val at 1st point 2.272532120614804
# GN step 8  and sol val at 1st point 2.272532120614804
# GN step 9  and sol val at 1st point 2.272532120614804
# GN step 0  and sol val at 1st point 2.2724718406463236
# GN step 1  and sol val at 1st point 2.2724618389272058
# GN step 2  and sol val at 1st point 2.2724618386990354
# GN step 3  and sol val at 1st point 2.2724618386990363
# GN step 4  and sol val at 1st point 2.272461838699037
# GN step 5  and sol val at 1st point 2.2724618386990367
# GN step 6  and sol val at 1st point 2.2724618386990367
# GN step 7  and sol val at 1st point 2.2724618386990367
# GN step 8  and sol val at 1st point 2.2724618386990367
# GN step 9  and sol val at 1st point 2.2724618386990367
# time t = 0.31 solved
# GN step 0  and sol val at 1st point 2.272382303548529
# GN step 1  and sol val at 1st point 2.272372994075625
# GN step 2  and sol val at 1st point 2.2723729942051536
# GN step 3  and sol val at 1st point 2.2723729942051802
# GN step 4  and sol val at 1st point 2.2723729942051847
# GN step 5  and sol val at 1st point 2.2723729942051847
# GN step 6  and sol val at 1st point 2.2723729942051847
# GN step 7  and sol val at 1st point 2.2723729942051847
# GN step 8  and sol val at 1st point 2.2723729942051847
# GN step 9  and sol val at 1st point 2.2723729942051847
# GN step 0  and sol val at 1st point 2.2723776741727644
# GN step 1  and sol val at 1st point 2.2723681085637955
# GN step 2  and sol val at 1st point 2.2723681087483856
# GN step 3  and sol val at 1st point 2.272368108748397
# GN step 4  and sol val at 1st point 2.2723681087484
# GN step 5  and sol val at 1st point 2.2723681087484
# GN step 6  and sol val at 1st point 2.2723681087484
# GN step 7  and sol val at 1st point 2.2723681087484
# GN step 8  and sol val at 1st point 2.2723681087484
# GN step 9  and sol val at 1st point 2.2723681087484
# GN step 0  and sol val at 1st point 2.2723566909870065
# GN step 1  and sol val at 1st point 2.27234737918256
# GN step 2  and sol val at 1st point 2.2723473792949838
# GN step 3  and sol val at 1st point 2.272347379294998
# GN step 4  and sol val at 1st point 2.2723473792949966
# GN step 5  and sol val at 1st point 2.2723473792949966
# GN step 6  and sol val at 1st point 2.2723473792949966
# GN step 7  and sol val at 1st point 2.2723473792949966
# GN step 8  and sol val at 1st point 2.2723473792949966
# GN step 9  and sol val at 1st point 2.2723473792949966
# GN step 0  and sol val at 1st point 2.2723126644854803
# GN step 1  and sol val at 1st point 2.2723028134056644
# GN step 2  and sol val at 1st point 2.2723028132981193
# GN step 3  and sol val at 1st point 2.2723028132981073
# GN step 4  and sol val at 1st point 2.272302813298108
# GN step 5  and sol val at 1st point 2.272302813298108
# GN step 6  and sol val at 1st point 2.272302813298108
# GN step 7  and sol val at 1st point 2.272302813298108
# GN step 8  and sol val at 1st point 2.272302813298108
# GN step 9  and sol val at 1st point 2.272302813298108
# GN step 0  and sol val at 1st point 2.2723071584484202
# GN step 1  and sol val at 1st point 2.272297843569379
# GN step 2  and sol val at 1st point 2.272297843566791
# GN step 3  and sol val at 1st point 2.2722978435667898
# GN step 4  and sol val at 1st point 2.272297843566788
# GN step 5  and sol val at 1st point 2.272297843566788
# GN step 6  and sol val at 1st point 2.272297843566788
# GN step 7  and sol val at 1st point 2.272297843566788
# GN step 8  and sol val at 1st point 2.272297843566788
# GN step 9  and sol val at 1st point 2.272297843566788
# GN step 0  and sol val at 1st point 2.2722738045867974
# GN step 1  and sol val at 1st point 2.272264361995652
# GN step 2  and sol val at 1st point 2.2722643618550156
# GN step 3  and sol val at 1st point 2.2722643618550107
# GN step 4  and sol val at 1st point 2.2722643618550116
# GN step 5  and sol val at 1st point 2.2722643618550116
# GN step 6  and sol val at 1st point 2.2722643618550116
# GN step 7  and sol val at 1st point 2.2722643618550116
# GN step 8  and sol val at 1st point 2.2722643618550116
# GN step 9  and sol val at 1st point 2.2722643618550116
# GN step 0  and sol val at 1st point 2.2722500341503906
# GN step 1  and sol val at 1st point 2.2722415400590954
# GN step 2  and sol val at 1st point 2.272241540004097
# GN step 3  and sol val at 1st point 2.2722415400041154
# GN step 4  and sol val at 1st point 2.272241540004118
# GN step 5  and sol val at 1st point 2.2722415400041185
# GN step 6  and sol val at 1st point 2.2722415400041185
# GN step 7  and sol val at 1st point 2.2722415400041185
# GN step 8  and sol val at 1st point 2.2722415400041185
# GN step 9  and sol val at 1st point 2.2722415400041185
# GN step 0  and sol val at 1st point 2.2722015719487607
# GN step 1  and sol val at 1st point 2.272192080321152
# GN step 2  and sol val at 1st point 2.272192080320796
# GN step 3  and sol val at 1st point 2.272192080320793
# GN step 4  and sol val at 1st point 2.272192080320792
# GN step 5  and sol val at 1st point 2.272192080320792
# GN step 6  and sol val at 1st point 2.272192080320792
# GN step 7  and sol val at 1st point 2.272192080320792
# GN step 8  and sol val at 1st point 2.272192080320792
# GN step 9  and sol val at 1st point 2.272192080320792
# GN step 0  and sol val at 1st point 2.272153176142885
# GN step 1  and sol val at 1st point 2.2721442310126663
# GN step 2  and sol val at 1st point 2.272144230985889
# GN step 3  and sol val at 1st point 2.272144230985903
# GN step 4  and sol val at 1st point 2.272144230985899
# GN step 5  and sol val at 1st point 2.272144230985899
# GN step 6  and sol val at 1st point 2.272144230985899
# GN step 7  and sol val at 1st point 2.272144230985899
# GN step 8  and sol val at 1st point 2.272144230985899
# GN step 9  and sol val at 1st point 2.272144230985899
# GN step 0  and sol val at 1st point 2.2721266449602022
# GN step 1  and sol val at 1st point 2.272117388493186
# GN step 2  and sol val at 1st point 2.2721173884130508
# GN step 3  and sol val at 1st point 2.272117388413037
# GN step 4  and sol val at 1st point 2.272117388413034
# GN step 5  and sol val at 1st point 2.272117388413035
# GN step 6  and sol val at 1st point 2.272117388413035
# GN step 7  and sol val at 1st point 2.272117388413035
# GN step 8  and sol val at 1st point 2.272117388413035
# GN step 9  and sol val at 1st point 2.272117388413035
# time t = 0.21 solved
# GN step 0  and sol val at 1st point 2.272073527950031
# GN step 1  and sol val at 1st point 2.272064327437997
# GN step 2  and sol val at 1st point 2.272064327524187
# GN step 3  and sol val at 1st point 2.272064327524215
# GN step 4  and sol val at 1st point 2.2720643275242143
# GN step 5  and sol val at 1st point 2.2720643275242125
# GN step 6  and sol val at 1st point 2.2720643275242125
# GN step 7  and sol val at 1st point 2.2720643275242125
# GN step 8  and sol val at 1st point 2.2720643275242125
# GN step 9  and sol val at 1st point 2.2720643275242125
# GN step 0  and sol val at 1st point 2.2720397887236516
# GN step 1  and sol val at 1st point 2.2720300593456684
# GN step 2  and sol val at 1st point 2.272030059351933
# GN step 3  and sol val at 1st point 2.272030059351933
# GN step 4  and sol val at 1st point 2.2720300593519323
# GN step 5  and sol val at 1st point 2.2720300593519314
# GN step 6  and sol val at 1st point 2.2720300593519314
# GN step 7  and sol val at 1st point 2.2720300593519314
# GN step 8  and sol val at 1st point 2.2720300593519314
# GN step 9  and sol val at 1st point 2.2720300593519314
# GN step 0  and sol val at 1st point 2.2719989795449465
# GN step 1  and sol val at 1st point 2.2719896964218886
# GN step 2  and sol val at 1st point 2.271989696313344
# GN step 3  and sol val at 1st point 2.271989696313348
# GN step 4  and sol val at 1st point 2.2719896963133452
# GN step 5  and sol val at 1st point 2.2719896963133457
# GN step 6  and sol val at 1st point 2.2719896963133457
# GN step 7  and sol val at 1st point 2.2719896963133457
# GN step 8  and sol val at 1st point 2.2719896963133457
# GN step 9  and sol val at 1st point 2.2719896963133457
# GN step 0  and sol val at 1st point 2.2719457285794276
# GN step 1  and sol val at 1st point 2.2719370774839773
# GN step 2  and sol val at 1st point 2.2719370775129715
# GN step 3  and sol val at 1st point 2.271937077512967
# GN step 4  and sol val at 1st point 2.271937077512968
# GN step 5  and sol val at 1st point 2.271937077512968
# GN step 6  and sol val at 1st point 2.271937077512968
# GN step 7  and sol val at 1st point 2.271937077512968
# GN step 8  and sol val at 1st point 2.271937077512968
# GN step 9  and sol val at 1st point 2.271937077512968
# GN step 0  and sol val at 1st point 2.271898576363189
# GN step 1  and sol val at 1st point 2.2718894092213167
# GN step 2  and sol val at 1st point 2.271889409198324
# GN step 3  and sol val at 1st point 2.2718894091983204
# GN step 4  and sol val at 1st point 2.27188940919832
# GN step 5  and sol val at 1st point 2.27188940919832
# GN step 6  and sol val at 1st point 2.27188940919832
# GN step 7  and sol val at 1st point 2.27188940919832
# GN step 8  and sol val at 1st point 2.27188940919832
# GN step 9  and sol val at 1st point 2.27188940919832
# GN step 0  and sol val at 1st point 2.271857219606178
# GN step 1  and sol val at 1st point 2.271848545775789
# GN step 2  and sol val at 1st point 2.2718485457504256
# GN step 3  and sol val at 1st point 2.271848545750429
# GN step 4  and sol val at 1st point 2.2718485457504287
# GN step 5  and sol val at 1st point 2.2718485457504287
# GN step 6  and sol val at 1st point 2.2718485457504287
# GN step 7  and sol val at 1st point 2.2718485457504287
# GN step 8  and sol val at 1st point 2.2718485457504287
# GN step 9  and sol val at 1st point 2.2718485457504287
# GN step 0  and sol val at 1st point 2.27182908714307
# GN step 1  and sol val at 1st point 2.2718200883743935
# GN step 2  and sol val at 1st point 2.2718200884522104
# GN step 3  and sol val at 1st point 2.271820088452209
# GN step 4  and sol val at 1st point 2.27182008845221
# GN step 5  and sol val at 1st point 2.27182008845221
# GN step 6  and sol val at 1st point 2.27182008845221
# GN step 7  and sol val at 1st point 2.27182008845221
# GN step 8  and sol val at 1st point 2.27182008845221
# GN step 9  and sol val at 1st point 2.27182008845221
# GN step 0  and sol val at 1st point 2.271762163790867
# GN step 1  and sol val at 1st point 2.2717534530208674
# GN step 2  and sol val at 1st point 2.271753453077343
# GN step 3  and sol val at 1st point 2.2717534530773387
# GN step 4  and sol val at 1st point 2.27175345307734
# GN step 5  and sol val at 1st point 2.27175345307734
# GN step 6  and sol val at 1st point 2.27175345307734
# GN step 7  and sol val at 1st point 2.27175345307734
# GN step 8  and sol val at 1st point 2.27175345307734
# GN step 9  and sol val at 1st point 2.27175345307734
# GN step 0  and sol val at 1st point 2.271742163227626
# GN step 1  and sol val at 1st point 2.2717332877390777
# GN step 2  and sol val at 1st point 2.271733287782836
# GN step 3  and sol val at 1st point 2.2717332877828333
# GN step 4  and sol val at 1st point 2.271733287782836
# GN step 5  and sol val at 1st point 2.271733287782836
# GN step 6  and sol val at 1st point 2.271733287782836
# GN step 7  and sol val at 1st point 2.271733287782836
# GN step 8  and sol val at 1st point 2.271733287782836
# GN step 9  and sol val at 1st point 2.271733287782836
# GN step 0  and sol val at 1st point 2.271694986813855
# GN step 1  and sol val at 1st point 2.271686126779385
# GN step 2  and sol val at 1st point 2.2716861267850335
# GN step 3  and sol val at 1st point 2.271686126785034
# GN step 4  and sol val at 1st point 2.2716861267850383
# GN step 5  and sol val at 1st point 2.2716861267850383
# GN step 6  and sol val at 1st point 2.2716861267850383
# GN step 7  and sol val at 1st point 2.2716861267850383
# GN step 8  and sol val at 1st point 2.2716861267850383
# GN step 9  and sol val at 1st point 2.2716861267850383
# time t = 0.11 solved
# GN step 0  and sol val at 1st point 2.271636619252337
# GN step 1  and sol val at 1st point 2.2716276611492296
# GN step 2  and sol val at 1st point 2.2716276612101476
# GN step 3  and sol val at 1st point 2.2716276612101454
# GN step 4  and sol val at 1st point 2.271627661210146
# GN step 5  and sol val at 1st point 2.271627661210146
# GN step 6  and sol val at 1st point 2.271627661210146
# GN step 7  and sol val at 1st point 2.271627661210146
# GN step 8  and sol val at 1st point 2.271627661210146
# GN step 9  and sol val at 1st point 2.271627661210146
# GN step 0  and sol val at 1st point 2.2715797719110764
# GN step 1  and sol val at 1st point 2.271570295357461
# GN step 2  and sol val at 1st point 2.271570295377986
# GN step 3  and sol val at 1st point 2.2715702953779906
# GN step 4  and sol val at 1st point 2.2715702953779906
# GN step 5  and sol val at 1st point 2.2715702953779906
# GN step 6  and sol val at 1st point 2.2715702953779906
# GN step 7  and sol val at 1st point 2.2715702953779906
# GN step 8  and sol val at 1st point 2.2715702953779906
# GN step 9  and sol val at 1st point 2.2715702953779906
# GN step 0  and sol val at 1st point 2.271534248931692
# GN step 1  and sol val at 1st point 2.271525497410798
# GN step 2  and sol val at 1st point 2.271525497411041
# GN step 3  and sol val at 1st point 2.2715254974110404
# GN step 4  and sol val at 1st point 2.27152549741104
# GN step 5  and sol val at 1st point 2.27152549741104
# GN step 6  and sol val at 1st point 2.27152549741104
# GN step 7  and sol val at 1st point 2.27152549741104
# GN step 8  and sol val at 1st point 2.27152549741104
# GN step 9  and sol val at 1st point 2.27152549741104
# GN step 0  and sol val at 1st point 2.271491562897433
# GN step 1  and sol val at 1st point 2.271482042338393
# GN step 2  and sol val at 1st point 2.2714820423082616
# GN step 3  and sol val at 1st point 2.2714820423082602
# GN step 4  and sol val at 1st point 2.271482042308259
# GN step 5  and sol val at 1st point 2.271482042308259
# GN step 6  and sol val at 1st point 2.271482042308259
# GN step 7  and sol val at 1st point 2.271482042308259
# GN step 8  and sol val at 1st point 2.271482042308259
# GN step 9  and sol val at 1st point 2.271482042308259
# GN step 0  and sol val at 1st point 2.271439754198461
# GN step 1  and sol val at 1st point 2.2714307766845643
# GN step 2  and sol val at 1st point 2.2714307766904382
# GN step 3  and sol val at 1st point 2.2714307766904414
# GN step 4  and sol val at 1st point 2.271430776690443
# GN step 5  and sol val at 1st point 2.271430776690443
# GN step 6  and sol val at 1st point 2.271430776690443
# GN step 7  and sol val at 1st point 2.271430776690443
# GN step 8  and sol val at 1st point 2.271430776690443
# GN step 9  and sol val at 1st point 2.271430776690443
# GN step 0  and sol val at 1st point 2.2713918364563126
# GN step 1  and sol val at 1st point 2.2713829046587453
# GN step 2  and sol val at 1st point 2.2713829046773357
# GN step 3  and sol val at 1st point 2.2713829046773344
# GN step 4  and sol val at 1st point 2.2713829046773366
# GN step 5  and sol val at 1st point 2.2713829046773366
# GN step 6  and sol val at 1st point 2.2713829046773366
# GN step 7  and sol val at 1st point 2.2713829046773366
# GN step 8  and sol val at 1st point 2.2713829046773366
# GN step 9  and sol val at 1st point 2.2713829046773366
# GN step 0  and sol val at 1st point 2.2713427541180278
# GN step 1  and sol val at 1st point 2.271333474807174
# GN step 2  and sol val at 1st point 2.271333474792322
# GN step 3  and sol val at 1st point 2.271333474792324
# GN step 4  and sol val at 1st point 2.2713334747923195
# GN step 5  and sol val at 1st point 2.2713334747923195
# GN step 6  and sol val at 1st point 2.2713334747923195
# GN step 7  and sol val at 1st point 2.2713334747923195
# GN step 8  and sol val at 1st point 2.2713334747923195
# GN step 9  and sol val at 1st point 2.2713334747923195
# GN step 0  and sol val at 1st point 2.2712995344601694
# GN step 1  and sol val at 1st point 2.2712906642002566
# GN step 2  and sol val at 1st point 2.271290664196225
# GN step 3  and sol val at 1st point 2.271290664196226
# GN step 4  and sol val at 1st point 2.271290664196224
# GN step 5  and sol val at 1st point 2.271290664196224
# GN step 6  and sol val at 1st point 2.271290664196224
# GN step 7  and sol val at 1st point 2.271290664196224
# GN step 8  and sol val at 1st point 2.271290664196224
# GN step 9  and sol val at 1st point 2.271290664196224
# GN step 0  and sol val at 1st point 2.2712416262776993
# GN step 1  and sol val at 1st point 2.271232635511229
# GN step 2  and sol val at 1st point 2.271232635501838
# GN step 3  and sol val at 1st point 2.2712326355018404
# GN step 4  and sol val at 1st point 2.271232635501841
# GN step 5  and sol val at 1st point 2.271232635501841
# GN step 6  and sol val at 1st point 2.271232635501841
# GN step 7  and sol val at 1st point 2.271232635501841
# GN step 8  and sol val at 1st point 2.271232635501841
# GN step 9  and sol val at 1st point 2.271232635501841
# GN step 0  and sol val at 1st point 2.2712040945643204
# GN step 1  and sol val at 1st point 2.2711946346012466
# GN step 2  and sol val at 1st point 2.2711946346006657
# GN step 3  and sol val at 1st point 2.271194634600666
# GN step 4  and sol val at 1st point 2.2711946346006653
# GN step 5  and sol val at 1st point 2.2711946346006653
# GN step 6  and sol val at 1st point 2.2711946346006653
# GN step 7  and sol val at 1st point 2.2711946346006653
# GN step 8  and sol val at 1st point 2.2711946346006653
# GN step 9  and sol val at 1st point 2.2711946346006653
# time t = 0.01 solved

# %%
print(V[-1,:])

# %%
print()
